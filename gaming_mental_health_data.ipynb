# %%
import pandas as pd

# %%
df = pd.read_csv(r'E:\Downloads\archive (2)\Gaming and Mental Health.csv')
df.head()
# Out:
#   record_id  age  gender  daily_gaming_hours     game_genre    primary_game  \
# 0    GD0001   17    Male                11.1   Mobile Games  Clash of Clans
# 1    GD0002   21    Male                 3.0           MOBA          Dota 2
# 2    GD0003   23    Male                 7.6            FPS           CS:GO
# 3    GD0004   20  Female                 7.2            RPG          Skyrim
# 4    GD0005   18    Male                 6.8  Battle Royale    Apex Legends
#
#   gaming_platform  sleep_hours sleep_quality sleep_disruption_frequency  ...  \
# 0              PC          3.7     Very Poor                  Sometimes  ...
# 1              PC          7.2          Fair                     Rarely  ...
# 2  Multi-platform          4.4          Fair                      Often  ...
# 3  Multi-platform          5.1          Fair                      Often  ...
# 4              PC          3.4          Poor                      Never  ...
#
#   continued_despite_problems  eye_strain  back_neck_pain weight_change_kg  \
# 0                       True        True           False              6.8
# 1                      False       False           False              0.4
# 2                       True       False            True              1.8
# 3                      False        True            True              0.2
# 4                      False       False           False              0.5
#
#   exercise_hours_weekly  social_isolation_score  \
# 0                   3.7                       7
# 1                   8.5                       2
# 2                   7.1                       5
# 3                   5.2                       4
# 4                   6.1                       4
#
#    face_to_face_social_hours_weekly  monthly_game_spending_usd  years_gaming  \
# 0                               1.3                     383.70             3
# 1                              10.7                      46.64             1
# 2                               3.2                     100.81             6
# 3                               9.1                      51.60             7
# 4                               4.5                      32.57             1
#
#    gaming_addiction_risk_level
# 0                       Severe
# 1                          Low
# 2                       Severe
# 3                         High
# 4                     Moderate
#
# [5 rows x 27 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 27 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   record_id                         1000 non-null   str
#  1   age                               1000 non-null   int64
#  2   gender                            1000 non-null   str
#  3   daily_gaming_hours                1000 non-null   float64
#  4   game_genre                        1000 non-null   str
#  5   primary_game                      1000 non-null   str
#  6   gaming_platform                   1000 non-null   str
#  7   sleep_hours                       1000 non-null   float64
#  8   sleep_quality                     1000 non-null   str
#  9   sleep_disruption_frequency        1000 non-null   str
#  10  academic_work_performance         1000 non-null   str
#  11  grades_gpa                        754 non-null    float64
#  12  work_productivity_score           674 non-null    float64
#  13  mood_state                        1000 non-null   str
#  14  mood_swing_frequency              1000 non-null   str
#  15  withdrawal_symptoms               1000 non-null   bool
#  16  loss_of_other_interests           1000 non-null   bool
#  17  continued_despite_problems        1000 non-null   bool
#  18  eye_strain                        1000 non-null   bool
#  19  back_neck_pain                    1000 non-null   bool
#  20  weight_change_kg                  1000 non-null   float64
#  21  exercise_hours_weekly             1000 non-null   float64
#  22  social_isolation_score            1000 non-null   int64
#  23  face_to_face_social_hours_weekly  1000 non-null   float64
#  24  monthly_game_spending_usd         1000 non-null   float64
#  25  years_gaming                      1000 non-null   int64
#  26  gaming_addiction_risk_level       1000 non-null   str
# dtypes: bool(5), float64(8), int64(3), str(11)
# memory usage: 176.9 KB

# %%
df.shape
# Out:
# (1000, 27)

# %%
df.value_counts()
# Out:
# record_id  age  gender  daily_gaming_hours  game_genre     primary_game       gaming_platform  sleep_hours  sleep_quality  sleep_disruption_frequency  academic_work_performance  grades_gpa  work_productivity_score  mood_state  mood_swing_frequency  withdrawal_symptoms  loss_of_other_interests  continued_despite_problems  eye_strain  back_neck_pain  weight_change_kg  exercise_hours_weekly  social_isolation_score  face_to_face_social_hours_weekly  monthly_game_spending_usd  years_gaming  gaming_addiction_risk_level
# GD0002     21   Male    3.0                 MOBA           Dota 2             PC               7.2          Fair           Rarely                      Good                       3.75        2.0                      Irritable   Often                 False                False                    False                       False       False           0.4               8.5                    2                       10.7                              46.64                      1             Low                            1
# GD0004     20   Female  7.2                 RPG            Skyrim             Multi-platform   5.1          Fair           Often                       Poor                       1.62        2.0                      Withdrawn   Daily                 True                 True                     False                       True        True            0.2               5.2                    4                       9.1                               51.60                      7             High                           1
# GD0006     21   Male    2.1                 Mobile Games   Clash of Clans     PC               7.5          Fair           Rarely                      Good                       3.81        4.0                      Normal      Never                 False                False                    False                       False       False           0.2               10.8                   1                       9.6                               8.63                       4             Low                            1
# GD0007     21   Male    2.7                 FPS            Call of Duty       Multi-platform   7.2          Very Poor      Often                       Below Average              1.82        6.0                      Euphoric    Rarely                False                False                    False                       False       False           0.8               10.0                   2                       10.1                              35.25                      3             Low                            1
# GD0014     22   Male    5.1                 RPG            Skyrim             Mobile           5.3          Fair           Never                       Average                    3.25        6.0                      Anxious     Rarely                False                False                    False                       True        False           0.9               7.6                    3                       6.3                               36.07                      5             Low                            1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ..
# GD0982     22   Female  13.6                Strategy       Civilization VI    Multi-platform   5.8          Poor           Rarely                      Failing                    2.92        5.0                      Irritable   Often                 True                 True                     False                       True        False           1.4               2.4                    8                       0.0                               438.83                     2             Severe                         1
# GD0988     19   Male    4.7                 MOBA           Dota 2             Console          6.7          Fair           Often                       Excellent                  2.02        10.0                     Restless    Often                 False                False                    False                       False       False           2.9               6.5                    2                       9.0                               59.91                      9             Low                            1
# GD0989     20   Male    4.4                 MMO            Final Fantasy XIV  PC               5.4          Very Poor      Sometimes                   Good                       2.26        5.0                      Euphoric    Sometimes             False                False                    False                       False       False           1.0               9.7                    3                       12.1                              8.08                       7             Low                            1
# GD0991     19   Female  7.0                 FPS            Valorant           PC               3.2          Fair           Often                       Poor                       3.00        1.0                      Anxious     Daily                 False                True                     False                       False       True            1.4               7.7                    5                       5.8                               121.06                     2             Moderate                       1
# GD0995     20   Female  9.3                 Battle Royale  Apex Legends       Console          5.8          Fair           Rarely                      Poor                       2.53        8.0                      Angry       Never                 False                True                     True                        False       False           0.4               4.4                    6                       6.1                               220.04                     10            Severe                         1
# Name: count, Length: 428, dtype: int64

# %%
df.describe()
# Out:
#                age  daily_gaming_hours  sleep_hours  grades_gpa  \
# count  1000.000000         1000.000000  1000.000000  754.000000
# mean     20.475000            6.151400     5.738100    2.518037
# std       4.116105            2.867194     1.441213    0.872312
# min      13.000000            0.500000     3.000000    1.010000
# 25%      18.000000            4.100000     4.800000    1.760000
# 50%      20.000000            6.000000     5.700000    2.530000
# 75%      22.000000            8.025000     6.600000    3.280000
# max      35.000000           15.100000     9.000000    4.000000
#
#        work_productivity_score  weight_change_kg  exercise_hours_weekly  \
# count               674.000000       1000.000000            1000.000000
# mean                  5.394659          1.513400               6.945900
# std                   2.898742          1.432212               1.805027
# min                   1.000000          0.000000               0.700000
# 25%                   3.000000          0.400000               5.700000
# 50%                   5.000000          1.100000               7.000000
# 75%                   8.000000          2.100000               8.200000
# max                  10.000000          8.900000              11.500000
#
#        social_isolation_score  face_to_face_social_hours_weekly  \
# count             1000.000000                       1000.000000
# mean                 3.872000                          7.654500
# std                  2.091409                          3.751954
# min                  1.000000                          0.000000
# 25%                  2.000000                          5.000000
# 50%                  4.000000                          8.000000
# 75%                  5.000000                         10.400000
# max                 10.000000                         16.700000
#
#        monthly_game_spending_usd  years_gaming
# count                1000.000000   1000.000000
# mean                  105.219730      5.796000
# std                   113.886768      3.775532
# min                     0.100000      1.000000
# 25%                    32.592500      3.000000
# 50%                    66.405000      5.000000
# 75%                   126.242500      8.000000
# max                   499.270000     20.000000

# %%
df.isnull().sum()
# Out:
# record_id                             0
# age                                   0
# gender                                0
# daily_gaming_hours                    0
# game_genre                            0
# primary_game                          0
# gaming_platform                       0
# sleep_hours                           0
# sleep_quality                         0
# sleep_disruption_frequency            0
# academic_work_performance             0
# grades_gpa                          246
# work_productivity_score             326
# mood_state                            0
# mood_swing_frequency                  0
# withdrawal_symptoms                   0
# loss_of_other_interests               0
# continued_despite_problems            0
# eye_strain                            0
# back_neck_pain                        0
# weight_change_kg                      0
# exercise_hours_weekly                 0
# social_isolation_score                0
# face_to_face_social_hours_weekly      0
# monthly_game_spending_usd             0
# years_gaming                          0
# gaming_addiction_risk_level           0
# dtype: int64

# %%
df.isna()
# Out:
#      record_id    age  gender  daily_gaming_hours  game_genre  primary_game  \
# 0        False  False   False               False       False         False
# 1        False  False   False               False       False         False
# 2        False  False   False               False       False         False
# 3        False  False   False               False       False         False
# 4        False  False   False               False       False         False
# ..         ...    ...     ...                 ...         ...           ...
# 995      False  False   False               False       False         False
# 996      False  False   False               False       False         False
# 997      False  False   False               False       False         False
# 998      False  False   False               False       False         False
# 999      False  False   False               False       False         False
#
#      gaming_platform  sleep_hours  sleep_quality  sleep_disruption_frequency  \
# 0              False        False          False                       False
# 1              False        False          False                       False
# 2              False        False          False                       False
# 3              False        False          False                       False
# 4              False        False          False                       False
# ..               ...          ...            ...                         ...
# 995            False        False          False                       False
# 996            False        False          False                       False
# 997            False        False          False                       False
# 998            False        False          False                       False
# 999            False        False          False                       False
#
#      ...  continued_despite_problems  eye_strain  back_neck_pain  \
# 0    ...                       False       False           False
# 1    ...                       False       False           False
# 2    ...                       False       False           False
# 3    ...                       False       False           False
# 4    ...                       False       False           False
# ..   ...                         ...         ...             ...
# 995  ...                       False       False           False
# 996  ...                       False       False           False
# 997  ...                       False       False           False
# 998  ...                       False       False           False
# 999  ...                       False       False           False
#
#      weight_change_kg  exercise_hours_weekly  social_isolation_score  \
# 0               False                  False                   False
# 1               False                  False                   False
# 2               False                  False                   False
# 3               False                  False                   False
# 4               False                  False                   False
# ..                ...                    ...                     ...
# 995             False                  False                   False
# 996             False                  False                   False
# 997             False                  False                   False
# 998             False                  False                   False
# 999             False                  False                   False
#
#      face_to_face_social_hours_weekly  monthly_game_spending_usd  \
# 0                               False                      False
# 1                               False                      False
# 2                               False                      False
# 3                               False                      False
# 4                               False                      False
# ..                                ...                        ...
# 995                             False                      False
# 996                             False                      False
# 997                             False                      False
# 998                             False                      False
# 999                             False                      False
#
#      years_gaming  gaming_addiction_risk_level
# 0           False                        False
# 1           False                        False
# 2           False                        False
# 3           False                        False
# 4           False                        False
# ..            ...                          ...
# 995         False                        False
# 996         False                        False
# 997         False                        False
# 998         False                        False
# 999         False                        False
#
# [1000 rows x 27 columns]

# %%
mystery_rows = df[df['grades_gpa'].isnull() & df['work_productivity_score'].isnull()]
print(f"Number of users with no school or work data: {len(mystery_rows)}")
# Out:
# Number of users with no school or work data: 0

# %%
# Create a clear 'Occupation' column
# If they have a GPA, they are a Student. Otherwise, they are a Professional.
df['Occupation'] = df['grades_gpa'].apply(lambda x: 'Student' if pd.notnull(x) else 'Professional')

# Double check the counts
print(df['Occupation'].value_counts())
# Out:
# Occupation
# Student         754
# Professional    246
# Name: count, dtype: int64

# %%
df.head()
# Out:
#   record_id  age  gender  daily_gaming_hours     game_genre    primary_game  \
# 0    GD0001   17    Male                11.1   Mobile Games  Clash of Clans
# 1    GD0002   21    Male                 3.0           MOBA          Dota 2
# 2    GD0003   23    Male                 7.6            FPS           CS:GO
# 3    GD0004   20  Female                 7.2            RPG          Skyrim
# 4    GD0005   18    Male                 6.8  Battle Royale    Apex Legends
#
#   gaming_platform  sleep_hours sleep_quality sleep_disruption_frequency  ...  \
# 0              PC          3.7     Very Poor                  Sometimes  ...
# 1              PC          7.2          Fair                     Rarely  ...
# 2  Multi-platform          4.4          Fair                      Often  ...
# 3  Multi-platform          5.1          Fair                      Often  ...
# 4              PC          3.4          Poor                      Never  ...
#
#   eye_strain  back_neck_pain  weight_change_kg exercise_hours_weekly  \
# 0       True           False               6.8                   3.7
# 1      False           False               0.4                   8.5
# 2      False            True               1.8                   7.1
# 3       True            True               0.2                   5.2
# 4      False           False               0.5                   6.1
#
#   social_isolation_score  face_to_face_social_hours_weekly  \
# 0                      7                               1.3
# 1                      2                              10.7
# 2                      5                               3.2
# 3                      4                               9.1
# 4                      4                               4.5
#
#    monthly_game_spending_usd  years_gaming  gaming_addiction_risk_level  \
# 0                     383.70             3                       Severe
# 1                      46.64             1                          Low
# 2                     100.81             6                       Severe
# 3                      51.60             7                         High
# 4                      32.57             1                     Moderate
#
#      Occupation
# 0       Student
# 1       Student
# 2  Professional
# 3       Student
# 4       Student
#
# [5 rows x 28 columns]

# %%
df.isnull().sum()
# Out:
# record_id                             0
# age                                   0
# gender                                0
# daily_gaming_hours                    0
# game_genre                            0
# primary_game                          0
# gaming_platform                       0
# sleep_hours                           0
# sleep_quality                         0
# sleep_disruption_frequency            0
# academic_work_performance             0
# grades_gpa                          246
# work_productivity_score             326
# mood_state                            0
# mood_swing_frequency                  0
# withdrawal_symptoms                   0
# loss_of_other_interests               0
# continued_despite_problems            0
# eye_strain                            0
# back_neck_pain                        0
# weight_change_kg                      0
# exercise_hours_weekly                 0
# social_isolation_score                0
# face_to_face_social_hours_weekly      0
# monthly_game_spending_usd             0
# years_gaming                          0
# gaming_addiction_risk_level           0
# Occupation                            0
# dtype: int64

# %%
df = df.fillna("N/A")
df
# Out:
#     record_id  age  gender  daily_gaming_hours     game_genre  \
# 0      GD0001   17    Male                11.1   Mobile Games
# 1      GD0002   21    Male                 3.0           MOBA
# 2      GD0003   23    Male                 7.6            FPS
# 3      GD0004   20  Female                 7.2            RPG
# 4      GD0005   18    Male                 6.8  Battle Royale
# ..        ...  ...     ...                 ...            ...
# 995    GD0996   15  Female                 8.6       Strategy
# 996    GD0997   18    Male                 5.4            MMO
# 997    GD0998   23    Male                 7.3            RPG
# 998    GD0999   18    Male                 3.1       Strategy
# 999    GD1000   29    Male                 3.5            RPG
#
#              primary_game gaming_platform  sleep_hours sleep_quality  \
# 0          Clash of Clans              PC          3.7     Very Poor
# 1                  Dota 2              PC          7.2          Fair
# 2                   CS:GO  Multi-platform          4.4          Fair
# 3                  Skyrim  Multi-platform          5.1          Fair
# 4            Apex Legends              PC          3.4          Poor
# ..                    ...             ...          ...           ...
# 995        Age of Empires              PC          4.1     Very Poor
# 996  Elder Scrolls Online  Multi-platform          6.5          Fair
# 997                Skyrim              PC          3.9      Insomnia
# 998          StarCraft II         Console          8.2          Fair
# 999        Cyberpunk 2077  Multi-platform          7.4          Good
#
#     sleep_disruption_frequency  ... eye_strain back_neck_pain  \
# 0                    Sometimes  ...       True          False
# 1                       Rarely  ...      False          False
# 2                        Often  ...      False           True
# 3                        Often  ...       True           True
# 4                        Never  ...      False          False
# ..                         ...  ...        ...            ...
# 995                     Always  ...       True           True
# 996                      Never  ...       True          False
# 997                     Rarely  ...      False           True
# 998                  Sometimes  ...      False          False
# 999                  Sometimes  ...      False          False
#
#     weight_change_kg exercise_hours_weekly social_isolation_score  \
# 0                6.8                   3.7                      7
# 1                0.4                   8.5                      2
# 2                1.8                   7.1                      5
# 3                0.2                   5.2                      4
# 4                0.5                   6.1                      4
# ..               ...                   ...                    ...
# 995              1.9                   7.5                      6
# 996              2.1                   7.7                      1
# 997              0.5                   8.1                      5
# 998              0.8                   8.4                      1
# 999              0.0                   9.3                      2
#
#      face_to_face_social_hours_weekly  monthly_game_spending_usd  \
# 0                                 1.3                     383.70
# 1                                10.7                      46.64
# 2                                 3.2                     100.81
# 3                                 9.1                      51.60
# 4                                 4.5                      32.57
# ..                                ...                        ...
# 995                               2.4                     426.54
# 996                              10.9                      83.71
# 997                               6.7                      88.60
# 998                              12.7                      22.02
# 999                              10.9                      25.20
#
#      years_gaming  gaming_addiction_risk_level    Occupation
# 0               3                       Severe       Student
# 1               1                          Low       Student
# 2               6                       Severe  Professional
# 3               7                         High       Student
# 4               1                     Moderate       Student
# ..            ...                          ...           ...
# 995             3                       Severe       Student
# 996             7                          Low       Student
# 997             5                         High  Professional
# 998             8                          Low       Student
# 999            19                          Low  Professional
#
# [1000 rows x 28 columns]

# %%
print(df[['grades_gpa', 'work_productivity_score', 'Occupation']].head(10))
# Out:
#   grades_gpa work_productivity_score    Occupation
# 0       1.25                     N/A       Student
# 1       3.75                     2.0       Student
# 2        N/A                     9.0  Professional
# 3       1.62                     2.0       Student
# 4       2.44                     N/A       Student
# 5       3.81                     4.0       Student
# 6       1.82                     6.0       Student
# 7        N/A                     1.0  Professional
# 8       2.43                     N/A       Student
# 9       1.13                     N/A       Student

# %%
df.dtypes
# Out:
# record_id                               str
# age                                   int64
# gender                                  str
# daily_gaming_hours                  float64
# game_genre                              str
# primary_game                            str
# gaming_platform                         str
# sleep_hours                         float64
# sleep_quality                           str
# sleep_disruption_frequency              str
# academic_work_performance               str
# grades_gpa                           object
# work_productivity_score              object
# mood_state                              str
# mood_swing_frequency                    str
# withdrawal_symptoms                    bool
# loss_of_other_interests                bool
# continued_despite_problems             bool
# eye_strain                             bool
# back_neck_pain                         bool
# weight_change_kg                    float64
# exercise_hours_weekly               float64
# social_isolation_score                int64
# face_to_face_social_hours_weekly    float64
# monthly_game_spending_usd           float64
# years_gaming                          int64
# gaming_addiction_risk_level             str
# Occupation                              str
# dtype: object

# %%
df['grades_gpa'] = pd.to_numeric(df['grades_gpa'], errors='coerce')
df
# Out:
#     record_id  age  gender  daily_gaming_hours     game_genre  \
# 0      GD0001   17    Male                11.1   Mobile Games
# 1      GD0002   21    Male                 3.0           MOBA
# 2      GD0003   23    Male                 7.6            FPS
# 3      GD0004   20  Female                 7.2            RPG
# 4      GD0005   18    Male                 6.8  Battle Royale
# ..        ...  ...     ...                 ...            ...
# 995    GD0996   15  Female                 8.6       Strategy
# 996    GD0997   18    Male                 5.4            MMO
# 997    GD0998   23    Male                 7.3            RPG
# 998    GD0999   18    Male                 3.1       Strategy
# 999    GD1000   29    Male                 3.5            RPG
#
#              primary_game gaming_platform  sleep_hours sleep_quality  \
# 0          Clash of Clans              PC          3.7     Very Poor
# 1                  Dota 2              PC          7.2          Fair
# 2                   CS:GO  Multi-platform          4.4          Fair
# 3                  Skyrim  Multi-platform          5.1          Fair
# 4            Apex Legends              PC          3.4          Poor
# ..                    ...             ...          ...           ...
# 995        Age of Empires              PC          4.1     Very Poor
# 996  Elder Scrolls Online  Multi-platform          6.5          Fair
# 997                Skyrim              PC          3.9      Insomnia
# 998          StarCraft II         Console          8.2          Fair
# 999        Cyberpunk 2077  Multi-platform          7.4          Good
#
#     sleep_disruption_frequency  ... eye_strain  back_neck_pain  \
# 0                    Sometimes  ...       True           False
# 1                       Rarely  ...      False           False
# 2                        Often  ...      False            True
# 3                        Often  ...       True            True
# 4                        Never  ...      False           False
# ..                         ...  ...        ...             ...
# 995                     Always  ...       True            True
# 996                      Never  ...       True           False
# 997                     Rarely  ...      False            True
# 998                  Sometimes  ...      False           False
# 999                  Sometimes  ...      False           False
#
#     weight_change_kg exercise_hours_weekly social_isolation_score  \
# 0                6.8                   3.7                      7
# 1                0.4                   8.5                      2
# 2                1.8                   7.1                      5
# 3                0.2                   5.2                      4
# 4                0.5                   6.1                      4
# ..               ...                   ...                    ...
# 995              1.9                   7.5                      6
# 996              2.1                   7.7                      1
# 997              0.5                   8.1                      5
# 998              0.8                   8.4                      1
# 999              0.0                   9.3                      2
#
#      face_to_face_social_hours_weekly  monthly_game_spending_usd  \
# 0                                 1.3                     383.70
# 1                                10.7                      46.64
# 2                                 3.2                     100.81
# 3                                 9.1                      51.60
# 4                                 4.5                      32.57
# ..                                ...                        ...
# 995                               2.4                     426.54
# 996                              10.9                      83.71
# 997                               6.7                      88.60
# 998                              12.7                      22.02
# 999                              10.9                      25.20
#
#      years_gaming  gaming_addiction_risk_level    Occupation
# 0               3                       Severe       Student
# 1               1                          Low       Student
# 2               6                       Severe  Professional
# 3               7                         High       Student
# 4               1                     Moderate       Student
# ..            ...                          ...           ...
# 995             3                       Severe       Student
# 996             7                          Low       Student
# 997             5                         High  Professional
# 998             8                          Low       Student
# 999            19                          Low  Professional
#
# [1000 rows x 28 columns]

# %%
df['work_productivity_score'] = pd.to_numeric(df['work_productivity_score'], errors='coerce')
df
# Out:
#     record_id  age  gender  daily_gaming_hours     game_genre  \
# 0      GD0001   17    Male                11.1   Mobile Games
# 1      GD0002   21    Male                 3.0           MOBA
# 2      GD0003   23    Male                 7.6            FPS
# 3      GD0004   20  Female                 7.2            RPG
# 4      GD0005   18    Male                 6.8  Battle Royale
# ..        ...  ...     ...                 ...            ...
# 995    GD0996   15  Female                 8.6       Strategy
# 996    GD0997   18    Male                 5.4            MMO
# 997    GD0998   23    Male                 7.3            RPG
# 998    GD0999   18    Male                 3.1       Strategy
# 999    GD1000   29    Male                 3.5            RPG
#
#              primary_game gaming_platform  sleep_hours sleep_quality  \
# 0          Clash of Clans              PC          3.7     Very Poor
# 1                  Dota 2              PC          7.2          Fair
# 2                   CS:GO  Multi-platform          4.4          Fair
# 3                  Skyrim  Multi-platform          5.1          Fair
# 4            Apex Legends              PC          3.4          Poor
# ..                    ...             ...          ...           ...
# 995        Age of Empires              PC          4.1     Very Poor
# 996  Elder Scrolls Online  Multi-platform          6.5          Fair
# 997                Skyrim              PC          3.9      Insomnia
# 998          StarCraft II         Console          8.2          Fair
# 999        Cyberpunk 2077  Multi-platform          7.4          Good
#
#     sleep_disruption_frequency  ... eye_strain  back_neck_pain  \
# 0                    Sometimes  ...       True           False
# 1                       Rarely  ...      False           False
# 2                        Often  ...      False            True
# 3                        Often  ...       True            True
# 4                        Never  ...      False           False
# ..                         ...  ...        ...             ...
# 995                     Always  ...       True            True
# 996                      Never  ...       True           False
# 997                     Rarely  ...      False            True
# 998                  Sometimes  ...      False           False
# 999                  Sometimes  ...      False           False
#
#      weight_change_kg exercise_hours_weekly social_isolation_score  \
# 0                 6.8                   3.7                      7
# 1                 0.4                   8.5                      2
# 2                 1.8                   7.1                      5
# 3                 0.2                   5.2                      4
# 4                 0.5                   6.1                      4
# ..                ...                   ...                    ...
# 995               1.9                   7.5                      6
# 996               2.1                   7.7                      1
# 997               0.5                   8.1                      5
# 998               0.8                   8.4                      1
# 999               0.0                   9.3                      2
#
#      face_to_face_social_hours_weekly  monthly_game_spending_usd  \
# 0                                 1.3                     383.70
# 1                                10.7                      46.64
# 2                                 3.2                     100.81
# 3                                 9.1                      51.60
# 4                                 4.5                      32.57
# ..                                ...                        ...
# 995                               2.4                     426.54
# 996                              10.9                      83.71
# 997                               6.7                      88.60
# 998                              12.7                      22.02
# 999                              10.9                      25.20
#
#      years_gaming  gaming_addiction_risk_level    Occupation
# 0               3                       Severe       Student
# 1               1                          Low       Student
# 2               6                       Severe  Professional
# 3               7                         High       Student
# 4               1                     Moderate       Student
# ..            ...                          ...           ...
# 995             3                       Severe       Student
# 996             7                          Low       Student
# 997             5                         High  Professional
# 998             8                          Low       Student
# 999            19                          Low  Professional
#
# [1000 rows x 28 columns]

# %%
df.dtypes
# Out:
# record_id                               str
# age                                   int64
# gender                                  str
# daily_gaming_hours                  float64
# game_genre                              str
# primary_game                            str
# gaming_platform                         str
# sleep_hours                         float64
# sleep_quality                           str
# sleep_disruption_frequency              str
# academic_work_performance               str
# grades_gpa                          float64
# work_productivity_score             float64
# mood_state                              str
# mood_swing_frequency                    str
# withdrawal_symptoms                    bool
# loss_of_other_interests                bool
# continued_despite_problems             bool
# eye_strain                             bool
# back_neck_pain                         bool
# weight_change_kg                    float64
# exercise_hours_weekly               float64
# social_isolation_score                int64
# face_to_face_social_hours_weekly    float64
# monthly_game_spending_usd           float64
# years_gaming                          int64
# gaming_addiction_risk_level             str
# Occupation                              str
# dtype: object

# %%
df.head()
# Out:
#   record_id  age  gender  daily_gaming_hours     game_genre    primary_game  \
# 0    GD0001   17    Male                11.1   Mobile Games  Clash of Clans
# 1    GD0002   21    Male                 3.0           MOBA          Dota 2
# 2    GD0003   23    Male                 7.6            FPS           CS:GO
# 3    GD0004   20  Female                 7.2            RPG          Skyrim
# 4    GD0005   18    Male                 6.8  Battle Royale    Apex Legends
#
#   gaming_platform  sleep_hours sleep_quality sleep_disruption_frequency  ...  \
# 0              PC          3.7     Very Poor                  Sometimes  ...
# 1              PC          7.2          Fair                     Rarely  ...
# 2  Multi-platform          4.4          Fair                      Often  ...
# 3  Multi-platform          5.1          Fair                      Often  ...
# 4              PC          3.4          Poor                      Never  ...
#
#   eye_strain  back_neck_pain  weight_change_kg exercise_hours_weekly  \
# 0       True           False               6.8                   3.7
# 1      False           False               0.4                   8.5
# 2      False            True               1.8                   7.1
# 3       True            True               0.2                   5.2
# 4      False           False               0.5                   6.1
#
#   social_isolation_score  face_to_face_social_hours_weekly  \
# 0                      7                               1.3
# 1                      2                              10.7
# 2                      5                               3.2
# 3                      4                               9.1
# 4                      4                               4.5
#
#    monthly_game_spending_usd  years_gaming  gaming_addiction_risk_level  \
# 0                     383.70             3                       Severe
# 1                      46.64             1                          Low
# 2                     100.81             6                       Severe
# 3                      51.60             7                         High
# 4                      32.57             1                     Moderate
#
#      Occupation
# 0       Student
# 1       Student
# 2  Professional
# 3       Student
# 4       Student
#
# [5 rows x 28 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
columns_to_sum = ['withdrawal_symptoms', 'loss_of_other_interests', 'continued_despite_problems']

df['addiction_severity_score'] = df[columns_to_sum].astype(int).sum(axis=1)

print(df[['withdrawal_symptoms', 'loss_of_other_interests', 'continued_despite_problems', 'addiction_severity_score']].head())
# Out:
#    withdrawal_symptoms  loss_of_other_interests  continued_despite_problems  \
# 0                 True                    False                        True
# 1                False                    False                       False
# 2                 True                     True                        True
# 3                 True                     True                       False
# 4                 True                    False                       False
#
#    addiction_severity_score
# 0                         2
# 1                         0
# 2                         3
# 3                         2
# 4                         1

# %%
df.head()
# Out:
#   record_id  age  gender  daily_gaming_hours     game_genre    primary_game  \
# 0    GD0001   17    Male                11.1   Mobile Games  Clash of Clans
# 1    GD0002   21    Male                 3.0           MOBA          Dota 2
# 2    GD0003   23    Male                 7.6            FPS           CS:GO
# 3    GD0004   20  Female                 7.2            RPG          Skyrim
# 4    GD0005   18    Male                 6.8  Battle Royale    Apex Legends
#
#   gaming_platform  sleep_hours sleep_quality sleep_disruption_frequency  ...  \
# 0              PC          3.7     Very Poor                  Sometimes  ...
# 1              PC          7.2          Fair                     Rarely  ...
# 2  Multi-platform          4.4          Fair                      Often  ...
# 3  Multi-platform          5.1          Fair                      Often  ...
# 4              PC          3.4          Poor                      Never  ...
#
#   back_neck_pain  weight_change_kg  exercise_hours_weekly  \
# 0          False               6.8                    3.7
# 1          False               0.4                    8.5
# 2           True               1.8                    7.1
# 3           True               0.2                    5.2
# 4          False               0.5                    6.1
#
#   social_isolation_score face_to_face_social_hours_weekly  \
# 0                      7                              1.3
# 1                      2                             10.7
# 2                      5                              3.2
# 3                      4                              9.1
# 4                      4                              4.5
#
#    monthly_game_spending_usd  years_gaming  gaming_addiction_risk_level  \
# 0                     383.70             3                       Severe
# 1                      46.64             1                          Low
# 2                     100.81             6                       Severe
# 3                      51.60             7                         High
# 4                      32.57             1                     Moderate
#
#      Occupation  addiction_severity_score
# 0       Student                         2
# 1       Student                         0
# 2  Professional                         3
# 3       Student                         2
# 4       Student                         1
#
# [5 rows x 29 columns]

# %%
cols = list(df.columns)

cols.remove('addiction_severity_score')
cols.remove('gaming_addiction_risk_level')

insert_pos = cols.index('continued_despite_problems') + 1

cols.insert(insert_pos, 'gaming_addiction_risk_level')
cols.insert(insert_pos + 1, 'addiction_severity_score')

df = df[cols]

print(df[['continued_despite_problems', 'gaming_addiction_risk_level', 'addiction_severity_score']].head())
# Out:
#    continued_despite_problems gaming_addiction_risk_level  \
# 0                        True                      Severe
# 1                       False                         Low
# 2                        True                      Severe
# 3                       False                        High
# 4                       False                    Moderate
#
#    addiction_severity_score
# 0                         2
# 1                         0
# 2                         3
# 3                         2
# 4                         1

# %%
df.head()
# Out:
#   record_id  age  gender  daily_gaming_hours     game_genre    primary_game  \
# 0    GD0001   17    Male                11.1   Mobile Games  Clash of Clans
# 1    GD0002   21    Male                 3.0           MOBA          Dota 2
# 2    GD0003   23    Male                 7.6            FPS           CS:GO
# 3    GD0004   20  Female                 7.2            RPG          Skyrim
# 4    GD0005   18    Male                 6.8  Battle Royale    Apex Legends
#
#   gaming_platform  sleep_hours sleep_quality sleep_disruption_frequency  ...  \
# 0              PC          3.7     Very Poor                  Sometimes  ...
# 1              PC          7.2          Fair                     Rarely  ...
# 2  Multi-platform          4.4          Fair                      Often  ...
# 3  Multi-platform          5.1          Fair                      Often  ...
# 4              PC          3.4          Poor                      Never  ...
#
#   addiction_severity_score  eye_strain  back_neck_pain weight_change_kg  \
# 0                        2        True           False              6.8
# 1                        0       False           False              0.4
# 2                        3       False            True              1.8
# 3                        2        True            True              0.2
# 4                        1       False           False              0.5
#
#   exercise_hours_weekly  social_isolation_score  \
# 0                   3.7                       7
# 1                   8.5                       2
# 2                   7.1                       5
# 3                   5.2                       4
# 4                   6.1                       4
#
#    face_to_face_social_hours_weekly  monthly_game_spending_usd years_gaming  \
# 0                               1.3                     383.70            3
# 1                              10.7                      46.64            1
# 2                               3.2                     100.81            6
# 3                               9.1                      51.60            7
# 4                               4.5                      32.57            1
#
#      Occupation
# 0       Student
# 1       Student
# 2  Professional
# 3       Student
# 4       Student
#
# [5 rows x 29 columns]

# %%
cols = df.columns.tolist()

anchor_idx = cols.index('work_productivity_score')

new_order = cols[:anchor_idx + 1] + [cols[-1]] + cols[anchor_idx + 1:-1]

df = df[new_order]

df
# Out:
#     record_id  age  gender  daily_gaming_hours     game_genre  \
# 0      GD0001   17    Male                11.1   Mobile Games
# 1      GD0002   21    Male                 3.0           MOBA
# 2      GD0003   23    Male                 7.6            FPS
# 3      GD0004   20  Female                 7.2            RPG
# 4      GD0005   18    Male                 6.8  Battle Royale
# ..        ...  ...     ...                 ...            ...
# 995    GD0996   15  Female                 8.6       Strategy
# 996    GD0997   18    Male                 5.4            MMO
# 997    GD0998   23    Male                 7.3            RPG
# 998    GD0999   18    Male                 3.1       Strategy
# 999    GD1000   29    Male                 3.5            RPG
#
#              primary_game gaming_platform  sleep_hours sleep_quality  \
# 0          Clash of Clans              PC          3.7     Very Poor
# 1                  Dota 2              PC          7.2          Fair
# 2                   CS:GO  Multi-platform          4.4          Fair
# 3                  Skyrim  Multi-platform          5.1          Fair
# 4            Apex Legends              PC          3.4          Poor
# ..                    ...             ...          ...           ...
# 995        Age of Empires              PC          4.1     Very Poor
# 996  Elder Scrolls Online  Multi-platform          6.5          Fair
# 997                Skyrim              PC          3.9      Insomnia
# 998          StarCraft II         Console          8.2          Fair
# 999        Cyberpunk 2077  Multi-platform          7.4          Good
#
#     sleep_disruption_frequency  ... gaming_addiction_risk_level  \
# 0                    Sometimes  ...                      Severe
# 1                       Rarely  ...                         Low
# 2                        Often  ...                      Severe
# 3                        Often  ...                        High
# 4                        Never  ...                    Moderate
# ..                         ...  ...                         ...
# 995                     Always  ...                      Severe
# 996                      Never  ...                         Low
# 997                     Rarely  ...                        High
# 998                  Sometimes  ...                         Low
# 999                  Sometimes  ...                         Low
#
#      addiction_severity_score  eye_strain back_neck_pain weight_change_kg  \
# 0                           2        True          False              6.8
# 1                           0       False          False              0.4
# 2                           3       False           True              1.8
# 3                           2        True           True              0.2
# 4                           1       False          False              0.5
# ..                        ...         ...            ...              ...
# 995                         2        True           True              1.9
# 996                         0        True          False              2.1
# 997                         2       False           True              0.5
# 998                         0       False          False              0.8
# 999                         0       False          False              0.0
#
#     exercise_hours_weekly  social_isolation_score  \
# 0                     3.7                       7
# 1                     8.5                       2
# 2                     7.1                       5
# 3                     5.2                       4
# 4                     6.1                       4
# ..                    ...                     ...
# 995                   7.5                       6
# 996                   7.7                       1
# 997                   8.1                       5
# 998                   8.4                       1
# 999                   9.3                       2
#
#      face_to_face_social_hours_weekly  monthly_game_spending_usd years_gaming
# 0                                 1.3                     383.70            3
# 1                                10.7                      46.64            1
# 2                                 3.2                     100.81            6
# 3                                 9.1                      51.60            7
# 4                                 4.5                      32.57            1
# ..                                ...                        ...          ...
# 995                               2.4                     426.54            3
# 996                              10.9                      83.71            7
# 997                               6.7                      88.60            5
# 998                              12.7                      22.02            8
# 999                              10.9                      25.20           19
#
# [1000 rows x 29 columns]

# %%
df.columns
# Out:
# Index(['record_id', 'age', 'gender', 'daily_gaming_hours', 'game_genre',
#        'primary_game', 'gaming_platform', 'sleep_hours', 'sleep_quality',
#        'sleep_disruption_frequency', 'academic_work_performance', 'grades_gpa',
#        'work_productivity_score', 'Occupation', 'mood_state',
#        'mood_swing_frequency', 'withdrawal_symptoms',
#        'loss_of_other_interests', 'continued_despite_problems',
#        'gaming_addiction_risk_level', 'addiction_severity_score', 'eye_strain',
#        'back_neck_pain', 'weight_change_kg', 'exercise_hours_weekly',
#        'social_isolation_score', 'face_to_face_social_hours_weekly',
#        'monthly_game_spending_usd', 'years_gaming'],
#       dtype='str')

# %%
df = df.rename(columns={
    'Occupation': 'occupation',
    'daily_gaming_hours': 'daily_hours',
    'academic_work_performance': 'academic_performance',
    'sleep_disruption_frequency': 'sleep_disruption',
    'mood_swing_frequency': 'mood_swings',
    'continued_despite_problems': 'continued_gaming',
    'gaming_addiction_risk_level': 'addiction_level',
    'addiction_severity_score': 'addiction_severity',
    'face_to_face_social_hours_weekly': 'in_person_hours_weekly',
    'social_isolation_score': 'social_isolation',
    'monthly_game_spending_usd': 'monthly_spend',
    'grades_gpa': 'gpa',
    'gaming_platform': 'platform',
    'game_genre': 'genre'
})
df.columns
# Out:
# Index(['record_id', 'age', 'gender', 'daily_hours', 'genre', 'primary_game',
#        'platform', 'sleep_hours', 'sleep_quality', 'sleep_disruption',
#        'academic_performance', 'gpa', 'work_productivity_score', 'occupation',
#        'mood_state', 'mood_swings', 'withdrawal_symptoms',
#        'loss_of_other_interests', 'continued_gaming', 'addiction_level',
#        'addiction_severity', 'eye_strain', 'back_neck_pain',
#        'weight_change_kg', 'exercise_hours_weekly', 'social_isolation',
#        'in_person_hours_weekly', 'monthly_spend', 'years_gaming'],
#       dtype='str')
